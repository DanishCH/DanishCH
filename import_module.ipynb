# %% [markdown]
# <a href="https://colab.research.google.com/github/DanishCH/DanishCH/blob/main/import_module.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import math
radius = float(input("Enter the radius of the circle: "))
area = math.pi * (radius ** 2)
print(f"Area of the circle is {area}")

# %%
import module_1

print(module_1.greeting())
